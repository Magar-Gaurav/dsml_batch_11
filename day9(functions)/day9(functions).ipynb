# %%
# Syntax:
def function_name():
  pass

# %%
# function to print sum of two numbers
def print_sum(a,b):
  print(f"The sum of {a} and {b} is {a + b}.")
print_sum(3,4)
# Out:
# The sum of 3 and 4 is 7.

# %%
# greet
def greet():
  print("Hello! Welcome to Python.")
  print("Have a great day.")
greet()
# Out:
# Hello! Welcome to Python.
# Have a great day.

# %%
# parameterized function with no return type
def print_name(name):
  print("Hello, ",name)
print_name("Saurav")
# Out:
# Hello,  Saurav

# %%
# no parameters, return type
def return_user():
  user_name = input("Enter your username: ")
  return user_name
name = return_user()
print(f"Hello, {name}")
# Out:
# Enter your username: Saurav
# Hello, Saurav

# %%
# has parameters, has return type
def sum(a,b):
  return a + b
total_sum = sum(4,5)
print("Sum : ",total_sum)
# Out:
# Sum :  9

# %%
# take username as imput then print good morning, limbu
def print_gm():
  user_name = input("Enter your username: ")
  print(f"Good morning, {user_name}")
print_gm()
# Out:
# Enter your username: limbu
# Good morning, limbu

# %%
# default parameter
def sum(a,b = 9):
  return a + b
sum(1)
# Out:
# 10

# %%
# write a python program using user definde function:
# takes two numbers from the user
# takes an opertor sign
# performs selected operation
# displays the result
def Calculator(a,b,operator):
  if operator == "+":
    return a + b
  elif operator == "-":
    return a - b
  elif operator == "*":
    return a * b
  elif operator == "/":
    return a / b
  else:
    print("Please input a valid opeator ( + , -, * , /)")
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
operator = input("Enter operator to perform operation(+,-,*,/):")
calculation = Calculator(a,b,operator)
print("Output:\n",calculation)
# Out:
# Enter first number: 5
# Enter second number: 4
# Enter operator to perform operation(+,-,*,/):/
# Output:
#  1.25

# %%
# Write a function area(length, breadth) that returns the area of rectangle
def Area(length,breadth):
  return length * breadth
length = float(input("Enter the value of length: "))
breadth = float(input("Enter the value of breadth: "))
print(f"The area is {Area(length,breadth)} meter square.")
# Out:
# Enter the value of length: 10
# Enter the value of breadth: 0
# The area is 0.0

# %%
# Write a user-defined function that takes 5 user inputs:
# if user enters an integer add it to a list
# if user enters a float number, remove the last element
# Finally display the updated list after each operation
def user_input():
  user_nums_list = []
  for i in range(5):
    num = input("Enter a number: ")
    if num.isdigit():
      user_nums_list.append(int(num))
    elif "." in num:
      user_nums_list.pop()
    print(user_nums_list)
user_input()
# Out:
# Enter a number: 10
# [10]
# Enter a number: 20
# [10, 20]
# Enter a number: 30
# [10, 20, 30]
# Enter a number: 40
# [10, 20, 30, 40]
# Enter a number: 50.5
# [10, 20, 30]
