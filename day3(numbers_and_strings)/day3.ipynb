# %%
""" Math Functions """
import math

print(math.sqrt(16))   
print(pow(2, 3))       
print(min(5, 10, 3))   
print(max(5, 10, 3))
# Out:
# 4.0
# 8
# 3
# 10

# %%
text = "Hello Python"
print(text[0:3])  
print(text[-3:])  
print(text[::-1])
# Out:
#   Cell In[2], line 1
#     text =
#            ^
# SyntaxError: invalid syntax
